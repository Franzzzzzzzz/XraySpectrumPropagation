# %%
import spekpy as sp
import numpy as np
import matplotlib.pyplot as plt

Dtd = 100 # distance tube detector in cm
s = sp.Spek(kvp=180,th=20, dk=0.5, z=Dtd, targ='W', char=False) # Generate a spectrum. char: include characteristics freq or not
s.filter('Be', 0.8) # Filter by 0.8 mm of Be

[freq, fluence] = s.get_spectrum()
plt.plot(freq,fluence, '.')

print(len(freq))
# Out:
# 358

# %%
SiO2 = np.genfromtxt("SiO2.dat", skip_header=1)
print(SiO2)
# Out:
# [[2.080733e+00 1.504378e+03]
#  [2.224304e+00 1.257719e+03]
#  [2.377781e+00 1.047994e+03]
#  [2.541848e+00 8.768062e+02]
#  [2.717235e+00 7.345910e+02]
#  [2.904724e+00 6.155705e+02]
#  [3.105150e+00 5.138641e+02]
#  [3.319406e+00 4.276404e+02]
#  [3.548445e+00 3.559471e+02]
#  [3.793288e+00 2.953563e+02]
#  [4.055024e+00 2.441705e+02]
#  [4.334821e+00 2.018864e+02]
#  [4.633924e+00 1.669528e+02]
#  [4.953664e+00 1.380946e+02]
#  [5.295467e+00 1.142396e+02]
#  [5.660855e+00 9.452536e+01]
#  [6.051453e+00 7.822932e+01]
#  [6.469004e+00 6.476321e+01]
#  [6.915365e+00 5.362649e+01]
#  [7.392525e+00 4.441910e+01]
#  [7.902609e+00 3.680429e+01]
#  [8.447890e+00 3.036659e+01]
#  [9.030794e+00 2.500806e+01]
#  [9.653919e+00 2.048467e+01]
#  [1.032004e+01 1.678412e+01]
#  [1.103212e+01 1.375720e+01]
#  [1.179334e+01 1.128602e+01]
#  [1.260708e+01 9.267116e+00]
#  [1.347697e+01 7.618048e+00]
#  [1.440688e+01 6.270639e+00]
#  [1.540095e+01 5.169256e+00]
#  [1.646362e+01 4.268873e+00]
#  [1.759961e+01 3.532436e+00]
#  [1.881398e+01 2.929869e+00]
#  [2.011215e+01 2.436645e+00]
#  [2.149988e+01 2.032812e+00]
#  [2.298338e+01 1.701901e+00]
#  [2.456923e+01 1.430591e+00]
#  [2.626450e+01 1.208037e+00]
#  [2.807676e+01 1.021608e+00]
#  [3.001405e+01 8.681017e-01]
#  [3.208502e+01 7.426583e-01]
#  [3.429889e+01 6.400272e-01]
#  [3.666551e+01 5.558733e-01]
#  [3.919543e+01 4.868000e-01]
#  [4.189992e+01 4.291393e-01]
#  [4.479101e+01 3.817670e-01]
#  [4.788159e+01 3.427302e-01]
#  [5.118542e+01 3.104502e-01]
#  [5.471721e+01 2.836576e-01]
#  [5.849270e+01 2.613151e-01]
#  [6.252870e+01 2.425810e-01]
#  [6.684318e+01 2.267791e-01]
#  [7.145536e+01 2.133636e-01]
#  [7.638578e+01 2.018823e-01]
#  [8.165640e+01 1.919650e-01]
#  [8.729069e+01 1.833320e-01]
#  [9.331374e+01 1.757248e-01]
#  [9.975239e+01 1.689794e-01]
#  [1.066353e+02 1.629188e-01]
#  [1.139931e+02 1.574254e-01]
#  [1.218587e+02 1.523887e-01]
#  [1.302669e+02 1.477397e-01]
#  [1.392553e+02 1.434057e-01]
#  [1.488640e+02 1.393306e-01]
#  [1.591356e+02 1.354771e-01]
#  [1.701159e+02 1.317964e-01]
#  [1.818539e+02 1.282758e-01]
#  [1.944018e+02 1.248960e-01]
#  [2.078156e+02 1.216289e-01]
#  [2.221548e+02 1.184599e-01]
#  [2.374835e+02 1.153902e-01]
#  [2.538699e+02 1.123945e-01]
#  [2.713869e+02 1.094942e-01]
#  [2.901126e+02 1.066538e-01]
#  [3.101304e+02 1.038795e-01]
#  [3.315294e+02 1.011874e-01]
#  [3.544049e+02 9.855175e-02]
#  [3.788588e+02 9.598171e-02]
#  [4.050001e+02 9.347538e-02]]

# %%
# %reload_ext autoreload
# %autoreload 2
import items
import importlib
importlib.reload(items)  
tube = items.tube(180,1)
D = items.detector()
#O1 = items.obj_sphere(np.array([0,0,500]), 10, "SiO2", 2.5, tube.freq)
#O2 = items.obj_sphere(np.array([0,10,100]), 10, "SiO2", 2.5, tube.freq)
#O1 = items.obj_box([0,0,500], [10,20,300], "SiO2", 1.5, tube.freq)
O1 = items.obj_cylinder([0,0,500], 20, 50, "SiO2", 2.5, tube.freq)
[res, resint]=items.image(tube,D, [O1])
# Out:
# Filters:  [('Be', 0.8)]

# %%
m = plt.imshow(resint, extent=D.extent())
fig=plt.gcf()
fig.colorbar(m)
plt.show()

plt.plot(tube.freq, res[0,0,:])
plt.plot(tube.freq, tube.fluence)

# %%
print("hello", "boo")
